# %%
import itertools
 
def gera_pemutacoes():
  sequencia = 'ABCDEF'
 
  nums = list(sequencia)
  permutations = list(itertools.permutations(nums))
 
  return [''.join(permutation) for permutation in permutations]
permutacoes = gera_pemutacoes()

# %%
def gera_comandos(sequencia):
  comandos = ''
  for comando in sequencia:
    match comando:
      case 'A': comandos += 'for (block_i = 0; block_i < n; block_i += block_size)\n'
      case 'B': comandos += 'for (block_j = 0; block_j < n; block_j += block_size)\n'
      case 'C': comandos += 'for (block_k = 0; block_k < n; block_k += block_size)\n'
      case 'D': comandos += 'for (i = 0; i < block_size; ++i)\n'
      case 'E': comandos += 'for (j = 0; j < block_size; ++j)\n'
      case 'F': comandos += 'for (k = 0; k < block_size; ++k)\n'
  return comandos

def gera_funcao(sequencia, block_size, algoritmo):
  codigo = f'''
void matrix_dgemm_2_{algoritmo}(int n, double *restrict _C, double *restrict _A, double *restrict _B)
{{
#define A(i, j) _A[n * (i) + (j)]
#define B(i, j) _B[n * (i) + (j)]
#define C(i, j) _C[n * (i) + (j)]

  int block_size = {block_size};
  int block_i, block_j, block_k;
  int i, j, k;

{gera_comandos(sequencia)}

  C(block_i + i, block_j + j) += A(block_i + i, block_k + k) * B(block_k + k, block_j + j);
  
#undef A
#undef B
#undef C
}} 

'''
  return codigo

def gera_matrix_h(algoritmo): 
  return f'void matrix_dgemm_2_{algoritmo}(int n, double *restrict _C, double *restrict _A, double *restrict _B);\n'

# %%
def gera_codigo():
  algoritmo = 0
  conteudo = ''
  block_sizes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
  for block_size in block_sizes:
    for permutacao in permutacoes:
      conteudo += gera_funcao(permutacao, block_size, algoritmo)
      algoritmo += 1

  algoritmo = 0
  for block_size in block_sizes:
    for permutacao in permutacoes: 
      conteudo += gera_matrix_h(algoritmo)
      algoritmo += 1
  
  conteudo += gera_matrix_which_dgemm_2()

  with open('codigo_gerado.c', 'w',encoding="utf-8") as file:
    file.write(conteudo)
  file.close()

gera_codigo()

# %%
gera_matrix_h(1)
# Out:
# 'void matrix_dgemm_2_1(int n, double *restrict _C, double *restrict _A, double *restrict _B);'

# %%
def gera_cases():
  conteudo = '' 
  algoritmo = 0
  block_sizes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
  for _ in block_sizes:
    for _ in permutacoes: 
      conteudo += f'''
      case {algoritmo}:
        matrix_dgemm_2_{algoritmo}(n, _C, _A, _B);
        ret = true;
        break;

      '''
      algoritmo += 1
  return conteudo


def gera_matrix_which_dgemm_2():
  conteudo = f'''
bool matrix_which_dgemm_2(int algorithm, int n, double *restrict _C, double *restrict _A, double *restrict _B)
{{
  bool ret;
  switch (algorithm)
  {{
  
  {gera_cases()}

  default:
    ret = false;
  }}
  return ret;
}}
'''
  return conteudo

gera_matrix_which_dgemm_2()
# Out:
# '\nbool matrix_which_dgemm_2(int algorithm, int n, double *restrict _C, double *restrict _A, double *restrict _B)\n{\n  bool ret;\n  switch (algorithm)\n  {\n  \n  \n      case 0:\n        matrix_dgemm_2_0(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 1:\n        matrix_dgemm_2_1(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 2:\n        matrix_dgemm_2_2(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 3:\n        matrix_dgemm_2_3(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 4:\n        matrix_dgemm_2_4(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 5:\n        matrix_dgemm_2_5(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 6:\n        matrix_dgemm_2_6(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 7:\n        matrix_dgemm_2_7(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 8:\n        matrix_dgemm_2_8(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 9:\n        matrix_dgemm_2_9(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 10:\n        matrix_dgemm_2_10(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 11:\n        matrix_dgemm_2_11(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 12:\n        matrix_dgemm_2_12(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 13:\n        matrix_dgemm_2_13(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 14:\n        matrix_dgemm_2_14(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 15:\n        matrix_dgemm_2_15(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 16:\n        matrix_dgemm_2_16(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 17:\n        matrix_dgemm_2_17(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 18:\n        matrix_dgemm_2_18(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 19:\n        matrix_dgemm_2_19(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 20:\n        matrix_dgemm_2_20(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 21:\n        matrix_dgemm_2_21(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 22:\n        matrix_dgemm_2_22(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 23:\n        matrix_dgemm_2_23(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 24:\n        matrix_dgemm_2_24(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 25:\n        matrix_dgemm_2_25(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 26:\n        matrix_dgemm_2_26(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 27:\n        matrix_dgemm_2_27(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 28:\n        matrix_dgemm_2_28(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 29:\n        matrix_dgemm_2_29(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 30:\n        matrix_dgemm_2_30(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 31:\n        matrix_dgemm_2_31(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 32:\n        matrix_dgemm_2_32(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 33:\n        matrix_dgemm_2_33(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 34:\n        matrix_dgemm_2_34(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 35:\n        matrix_dgemm_2_35(n, _C, _A, _B);\n        ret = true;\n        break;\n\n      \n      case 36:\n        matrix_dgemm_2 ...

# %%
def generate_bench():
  conteudo = '#!/bin/bash\n\n' 
  algoritmo = 0
  total = len(permutacoes) * len(block_sizes)
  for _ in block_sizes:
    for _ in permutacoes:
      conteudo += f'''
      echo "{algoritmo}/{total}"
      echo "{algoritmo},$(./main-experiment --matrix-size 2048 --algorithm {algoritmo})" >> experimento.csv \n'''
      algoritmo += 1
  with open('experiment.sh', 'w',encoding="utf-8") as file:
    file.write(conteudo)
  file.close()

generate_bench()

# %%
import optuna
import tqdm as notebook_tqdm
import subprocess

block_sizes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]


def run(permutacao, block_size):
  algoritmo = str(block_sizes.index(block_size) * 720 + permutacoes.index(permutacao))
  timeout_s = 15  # em segundos
  cmd = ['./main-experiment', '--matrix-size', '2048', '--algorithm', algoritmo]
  try:
    result = subprocess.run(cmd, shell=False, capture_output=True, timeout=timeout_s, universal_newlines=True)
    return float(result.stdout)
  except subprocess.TimeoutExpired as e:
    return float(100)
  

def objective(trial):
  permutacao = trial.suggest_categorical("sequence", permutacoes)
  block_size = trial.suggest_categorical("block_size", block_sizes)

  return run(permutacao, block_size)

def tenta():
  study = optuna.create_study(
    storage="sqlite:///db.sqlite3",
    study_name="miniEP6",
    load_if_exists=True
  )
  study.optimize(objective, n_trials=1000)
  print(f"Best value: {study.best_value} (params: {study.best_params})")




tenta()
# Out:
# [I 2023-05-07 14:03:40,285] Using an existing study with name 'miniEP6' instead of creating a new one.
# [I 2023-05-07 14:03:55,578] Trial 422 finished with value: 14.585804 and parameters: {'sequence': 'DCFAEB', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:04:10,845] Trial 423 finished with value: 100.0 and parameters: {'sequence': 'BECFDA', 'block_size': 8}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:04:26,113] Trial 424 finished with value: 100.0 and parameters: {'sequence': 'AEDBFC', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:04:41,484] Trial 425 finished with value: 100.0 and parameters: {'sequence': 'ADFEBC', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:04:56,842] Trial 426 finished with value: 100.0 and parameters: {'sequence': 'AFECDB', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:05:12,319] Trial 427 finished with value: 100.0 and parameters: {'sequence': 'ADCBFE', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:05:27,857] Trial 428 finished with value: 100.0 and parameters: {'sequence': 'FCBDEA', 'block_size': 64}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:05:43,521] Trial 429 finished with value: 100.0 and parameters: {'sequence': 'EACDFB', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:05:59,272] Trial 430 finished with value: 100.0 and parameters: {'sequence': 'ECDBAF', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:06:14,995] Trial 431 finished with value: 100.0 and parameters: {'sequence': 'ECADBF', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:06:30,753] Trial 432 finished with value: 100.0 and parameters: {'sequence': 'ABDFCE', 'block_size': 8}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:06:46,507] Trial 433 finished with value: 100.0 and parameters: {'sequence': 'BEFDCA', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:07:02,243] Trial 434 finished with value: 100.0 and parameters: {'sequence': 'ABFDCE', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:07:18,088] Trial 435 finished with value: 100.0 and parameters: {'sequence': 'CFADEB', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:07:34,079] Trial 436 finished with value: 100.0 and parameters: {'sequence': 'BAFEDC', 'block_size': 32}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:07:50,068] Trial 437 finished with value: 100.0 and parameters: {'sequence': 'ECBAFD', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:08:05,967] Trial 438 finished with value: 100.0 and parameters: {'sequence': 'EDFBAC', 'block_size': 64}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:08:21,551] Trial 439 finished with value: 100.0 and parameters: {'sequence': 'FBCAED', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:08:37,671] Trial 440 finished with value: 100.0 and parameters: {'sequence': 'BDEACF', 'block_size': 16}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:08:53,701] Trial 441 finished with value: 100.0 and parameters: {'sequence': 'DEBCFA', 'block_size': 256}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:09:09,900] Trial 442 finished with value: 100.0 and parameters: {'sequence': 'AEBDFC', 'block_size': 8}. Best is trial 374 with value: 6.799146.
# [I 2023-05-07 14:09:26,047] Trial 443 finished with value: 100.0 and parameters: {'sequence': 'CBFADE', 'block_size': 512}. Best is trial 374 with value: 6.799146.
# [W 2023-05-07 14:09:30,350] Trial 444 failed with parameters: {'sequence': 'FEBACD', 'block_size': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/diogoalves/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_3544286/3222962097.py", line 24, in objective
#     return run(permutacao, block_size)
#   File "/tmp/ipykernel_3544286/3222962097.py", line 14, in run
#     result = subprocess.run(cmd, shell=True, capture_output=True, timeout=timeout_s, universal_newlines=True)
#   File "/home/diogoalves/mambaforge/envs/py310/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/home/diogoalves/mambaforge/envs/py310/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/diogoalves/mambaforge/envs/py310/lib/python3.10/subprocess.py", line 2005, in _communicate
#     ready = selector.select(timeout)
#   File "/home/diogoalves/mambaforge/envs/py310/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
# [W 2023-05-07 14:09:30,355] Trial 444 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 38
#      32   study.optimize(objective, n_trials=1000)
#      33   print(f"Best value: {study.best_value} (params: {study.best_params})")
# ---> 38 tenta()
#
# Cell In[112], line 32, in tenta()
#      26 def tenta():
#      27   study = optuna.create_study(
#      28     storage="sqlite:///db.sqlite3",
#      29     study_name="miniEP6",
#      30     load_if_exists=True
#      31   )
# ---> 32   study.optimize(objective, n_trials=1000)
#      33   print(f"Best value: {study.best_value} (params: {study.best_params})")
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/study.py:425, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     321 def optimize(
#     322     self,
#     323     func: ObjectiveFuncType,
#    (...)
#     330     show_progress_bar: bool = False,
#     331 ) -> None:
#     332     """Optimize an objective function.
#     333
#     334     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     422             If nested invocation of this method occurs.
#     423     """
# --> 425     _optimize(
#     426         study=self,
#     427         func=func,
#     428         n_trials=n_trials,
#     429         timeout=timeout,
#     430         n_jobs=n_jobs,
#     431         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     432         callbacks=callbacks,
#     433         gc_after_trial=gc_after_trial,
#     434         show_progress_bar=show_progress_bar,
#     435     )
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[112], line 24, in objective(trial)
#      21 permutacao = trial.suggest_categorical("sequence", permutacoes)
#      22 block_size = trial.suggest_categorical("block_size", block_sizes)
# ---> 24 return run(permutacao, block_size)
#
# Cell In[112], line 14, in run(permutacao, block_size)
#      11 cmd = f"./main-experiment --matrix-size 2048 --algorithm {algoritmo}"
#      13 try:
# ---> 14   result = subprocess.run(cmd, shell=True, capture_output=True, timeout=timeout_s, universal_newlines=True)
#      15   return float(result.stdout)
#      16 except subprocess.TimeoutExpired as e:
#
# File ~/mambaforge/envs/py310/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/mambaforge/envs/py310/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/mambaforge/envs/py310/lib/python3.10/subprocess.py:2005, in Popen._communicate(self, input, endtime, orig_timeout)
#    1998     self._check_timeout(endtime, orig_timeout,
#    1999                         stdout, stderr,
#    2000                         skip_check_and_raise=True)
#    2001     raise RuntimeError(  # Impossible :)
#    2002         '_check_timeout(..., skip_check_and_raise=True) '
#    2003         'failed to raise TimeoutExpired.')
# -> 2005 ready = selector.select(timeout)
#    2006 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2008 # XXX Rewrite these to use non-blocking I/O on the file
#    2009 # objects; they are no longer using C stdio!
#
# File ~/mambaforge/envs/py310/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
import optuna
import tqdm as notebook_tqdm
import subprocess

block_sizes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

def run(permutacao, block_size):
  algoritmo = str(block_sizes.index(block_size) * 720 + permutacoes.index(permutacao))
  timeout_s = 15  # em segundos
  cmd = ['./main-experiment', '--matrix-size', '2048', '--algorithm', algoritmo]
  try:
    result = subprocess.run(cmd, shell=False, capture_output=True, timeout=timeout_s, universal_newlines=True)
    return float(result.stdout)
  except subprocess.TimeoutExpired as e:
    return float(100)
  
  
run('ACDBFE', 512)
# Out:
# 0.736256

# %%
block_sizes = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

for b in block_sizes:
  print(str(block_sizes.index(b) * 720 + permutacoes.index('ACDBEF')))
# Out:
# 30
# 750
# 1470
# 2190
# 2910
# 3630
# 4350
# 5070
# 5790
# 6510
